# %%
from kafka import KafkaProducer
from datetime import datetime
import time
from json import dumps
import random
from configparser import ConfigParser
from manage_kafka_topics import KafkaTopicManager

# %%
conf_file_name = "streaming_app.conf"
config_obj = ConfigParser()
config_read_obj = config_obj.read(conf_file_name)
print(config_obj.sections())
# Out:
# ['kafka']

# %%
# Kafka Cluster/Server Details
kafka_host_name = config_obj.get('kafka', 'host')
kafka_port_no = config_obj.get('kafka', 'port_no')
kafka_topic_name = config_obj.get('kafka', 'topic_name')

k_t_m = KafkaTopicManager(kafka_host_name, kafka_port_no)
k_t_m.create_topic(kafka_topic_name)
KAFKA_TOPIC_NAME_CONST = kafka_topic_name
KAFKA_BOOTSTRAP_SERVERS_CONST = kafka_host_name + ':' + kafka_port_no
# Out:
# Kafka Topic previously created is available

# %%
# Sample data
# {"order_id": 101, "order_date": "2021-02-06 07:55:00", "order_amount": 100}

kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONST,
                                   value_serializer=lambda x: dumps(x).encode('utf-8'))


product_name_list = ["Laptop", "Desktop Computer", "Mobile Phone", "Wrist Band", "Wrist Watch", "LAN Cable",
                     "HDMI Cable", "TV", "TV Stand", "Text Books", "External Hard Drive", "Pen Drive"]

order_card_type_list = ['Visa', 'Master', 'Maestro', 'American Express', 'PhonePe', 'PayPal']

country_name_city_name_list = ["Sydney,Australia", "Florida,United States", "New York City,United States",
                               "Paris,France", "Colombo,Sri Lanka", "Dhaka,Bangladesh", "Islamabad,Pakistan",
                               "Beijing,China", "Rome,Italy", "Berlin,Germany", "Ottawa,Canada",
                               "London,United Kingdom", "Jerusalem,Israel", "Bangkok,Thailand",
                               "Chennai,India", "Bangalore,India", "Mumbai,India", "Pune,India",
                               "New Delhi,Inida", "Hyderabad,India", "Kolkata,India", "Singapore,Singapore"]

ecommerce_website_name_list = ["www.amazon.com", "www.flipkart.com", "www.snapdeal.com", "www.ebay.com"]

message_list = []
message = None
for ind, it_ in enumerate(range(100)):
    message = {}
    print("Preparing message: " + str(ind))
    event_datetime = datetime.now()

    message["order_id"] = str(ind)
    message["order_product_name"] = random.choice(product_name_list)
    message["order_card_type"] = random.choice(order_card_type_list)
    message["order_amount"] = round(random.uniform(5.5, 1555.5), 2)
    message["order_datetime"] = event_datetime.strftime("%Y-%m-%d %H:%M:%S")
    location = random.choice(country_name_city_name_list)
    message["order_location"] = location
    message["order_ecommerce_source"] = random.choice(ecommerce_website_name_list)

    print("Message: ", message)
    kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONST, message)
    time.sleep(1)

print("Kafka Producer Application Completed. ")
# Out:
# Preparing message: 0
# Message:  {'order_id': '0', 'order_product_name': 'Wrist Watch', 'order_card_type': 'American Express', 'order_amount': 296.1, 'order_datetime': '2024-05-10 17:52:09', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 1
# Message:  {'order_id': '1', 'order_product_name': 'Desktop Computer', 'order_card_type': 'American Express', 'order_amount': 267.29, 'order_datetime': '2024-05-10 17:52:10', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 2
# Message:  {'order_id': '2', 'order_product_name': 'Pen Drive', 'order_card_type': 'Visa', 'order_amount': 145.72, 'order_datetime': '2024-05-10 17:52:11', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 3
# Message:  {'order_id': '3', 'order_product_name': 'HDMI Cable', 'order_card_type': 'American Express', 'order_amount': 1082.02, 'order_datetime': '2024-05-10 17:52:12', 'order_location': 'New York City,United States', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 4
# Message:  {'order_id': '4', 'order_product_name': 'Mobile Phone', 'order_card_type': 'American Express', 'order_amount': 217.09, 'order_datetime': '2024-05-10 17:52:13', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 5
# Message:  {'order_id': '5', 'order_product_name': 'Wrist Watch', 'order_card_type': 'Maestro', 'order_amount': 823.24, 'order_datetime': '2024-05-10 17:52:14', 'order_location': 'New York City,United States', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 6
# Message:  {'order_id': '6', 'order_product_name': 'Desktop Computer', 'order_card_type': 'Master', 'order_amount': 1351.25, 'order_datetime': '2024-05-10 17:52:15', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 7
# Message:  {'order_id': '7', 'order_product_name': 'LAN Cable', 'order_card_type': 'Master', 'order_amount': 1214.52, 'order_datetime': '2024-05-10 17:52:16', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 8
# Message:  {'order_id': '8', 'order_product_name': 'Text Books', 'order_card_type': 'Visa', 'order_amount': 814.02, 'order_datetime': '2024-05-10 17:52:17', 'order_location': 'Berlin,Germany', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 9
# Message:  {'order_id': '9', 'order_product_name': 'TV', 'order_card_type': 'PhonePe', 'order_amount': 1401.08, 'order_datetime': '2024-05-10 17:52:18', 'order_location': 'Rome,Italy', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 10
# Message:  {'order_id': '10', 'order_product_name': 'Laptop', 'order_card_type': 'PhonePe', 'order_amount': 523.99, 'order_datetime': '2024-05-10 17:52:19', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 11
# Message:  {'order_id': '11', 'order_product_name': 'Wrist Band', 'order_card_type': 'PhonePe', 'order_amount': 154.69, 'order_datetime': '2024-05-10 17:52:20', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 12
# Message:  {'order_id': '12', 'order_product_name': 'LAN Cable', 'order_card_type': 'Visa', 'order_amount': 754.22, 'order_datetime': '2024-05-10 17:52:21', 'order_location': 'Bangalore,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 13
# Message:  {'order_id': '13', 'order_product_name': 'HDMI Cable', 'order_card_type': 'Maestro', 'order_amount': 1335.45, 'order_datetime': '2024-05-10 17:52:22', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 14
# Message:  {'order_id': '14', 'order_product_name': 'Pen Drive', 'order_card_type': 'PayPal', 'order_amount': 188.72, 'order_datetime': '2024-05-10 17:52:23', 'order_location': 'Bangalore,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 15
# Message:  {'order_id': '15', 'order_product_name': 'TV Stand', 'order_card_type': 'PhonePe', 'order_amount': 226.09, 'order_datetime': '2024-05-10 17:52:24', 'order_location': 'Rome,Italy', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 16
# Message:  {'order_id': '16', 'order_product_name': 'Wrist Band', 'order_card_type': 'PayPal', 'order_amount': 352.65, 'order_datetime': '2024-05-10 17:52:25', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 17
# Message:  {'order_id': '17', 'order_product_name': 'TV Stand', 'order_card_type': 'Master', 'order_amount': 761.5, 'order_datetime': '2024-05-10 17:52:26', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 18
# Message:  {'order_id': '18', 'order_product_name': 'Mobile Phone', 'order_card_type': 'American Express', 'order_amount': 1027.15, 'order_datetime': '2024-05-10 17:52:27', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 19
# Message:  {'order_id': '19', 'order_product_name': 'Pen Drive', 'order_card_type': 'PhonePe', 'order_amount': 183.02, 'order_datetime': '2024-05-10 17:52:28', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 20
# Message:  {'order_id': '20', 'order_product_name': 'Desktop Computer', 'order_card_type': 'PayPal', 'order_amount': 17.03, 'order_datetime': '2024-05-10 17:52:29', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 21
# Message:  {'order_id': '21', 'order_product_name': 'TV Stand', 'order_card_type': 'Visa', 'order_amount': 140.15, 'order_datetime': '2024-05-10 17:52:30', 'order_location': 'Kolkata,India', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 22
# Message:  {'order_id': '22', 'order_product_name': 'Wrist Band', 'order_card_type': 'Maestro', 'order_amount': 180.34, 'order_datetime': '2024-05-10 17:52:31', 'order_location': 'Kolkata,India', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 23
# Message:  {'order_id': '23', 'order_product_name': 'LAN Cable', 'order_card_type': 'PayPal', 'order_amount': 904.99, 'order_datetime': '2024-05-10 17:52:32', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 24
# Message:  {'order_id': '24', 'order_product_name': 'Wrist Band', 'order_card_type': 'Master', 'order_amount': 943.74, 'order_datetime': '2024-05-10 17:52:33', 'order_location': 'Paris,France', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 25
# Message:  {'order_id': '25', 'order_product_name': 'Wrist Watch', 'order_card_type': 'American Express', 'order_amount': 1537.59, 'order_datetime': '2024-05-10 17:52:34', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 26
# Message:  {'order_id': '26', 'order_product_name': 'TV Stand', 'order_card_type': 'PayPal', 'order_amount': 114.65, 'order_datetime': '2024-05-10 17:52:35', 'order_location': 'Bangalore,India', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 27
# Message:  {'order_id': '27', 'order_product_name': 'Desktop Computer', 'order_card_type': 'Maestro', 'order_amount': 11.25, 'order_datetime': '2024-05-10 17:52:36', 'order_location': 'Colombo,Sri Lanka', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 28
# Message:  {'order_id': '28', 'order_product_name': 'Pen Drive', 'order_card_type': 'Maestro', 'order_amount': 803.01, 'order_datetime': '2024-05-10 17:52:37', 'order_location': 'Berlin,Germany', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 29
# Message:  {'order_id': '29', 'order_product_name': 'HDMI Cable', 'order_card_type': 'Visa', 'order_amount': 1420.78, 'order_datetime': '2024-05-10 17:52:38', 'order_location': 'Rome,Italy', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 30
# Message:  {'order_id': '30', 'order_product_name': 'External Hard Drive', 'order_card_type': 'PhonePe', 'order_amount': 333.55, 'order_datetime': '2024-05-10 17:52:39', 'order_location': 'London,United Kingdom', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 31
# Message:  {'order_id': '31', 'order_product_name': 'TV', 'order_card_type': 'PhonePe', 'order_amount': 578.91, 'order_datetime': '2024-05-10 17:52:40', 'order_location': 'London,United Kingdom', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 32
# Message:  {'order_id': '32', 'order_product_name': 'Mobile Phone', 'order_card_type': 'Maestro', 'order_amount': 177.27, 'order_datetime': '2024-05-10 17:52:41', 'order_location': 'Florida,United States', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 33
# Message:  {'order_id': '33', 'order_product_name': 'HDMI Cable', 'order_card_type': 'Master', 'order_amount': 586.1, 'order_datetime': '2024-05-10 17:52:42', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 34
# Message:  {'order_id': '34', 'order_product_name': 'Pen Drive', 'order_card_type': 'Maestro', 'order_amount': 297.37, 'order_datetime': '2024-05-10 17:52:43', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 35
# Message:  {'order_id': '35', 'order_product_name': 'TV', 'order_card_type': 'Maestro', 'order_amount': 1129.5, 'order_datetime': '2024-05-10 17:52:44', 'order_location': 'Mumbai,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 36
# Message:  {'order_id': '36', 'order_product_name': 'Text Books', 'order_card_type': 'Maestro', 'order_amount': 648.76, 'order_datetime': '2024-05-10 17:52:45', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 37
# Message:  {'order_id': '37', 'order_product_name': 'Text Books', 'order_card_type': 'Master', 'order_amount': 1536.5, 'order_datetime': '2024-05-10 17:52:46', 'order_location': 'Kolkata,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 38
# Message:  {'order_id': '38', 'order_product_name': 'Mobile Phone', 'order_card_type': 'PayPal', 'order_amount': 930.26, 'order_datetime': '2024-05-10 17:52:47', 'order_location': 'Kolkata,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 39
# Message:  {'order_id': '39', 'order_product_name': 'Pen Drive', 'order_card_type': 'Master', 'order_amount': 1054.29, 'order_datetime': '2024-05-10 17:52:48', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 40
# Message:  {'order_id': '40', 'order_product_name': 'Mobile Phone', 'order_card_type': 'PayPal', 'order_amount': 328.04, 'order_datetime': '2024-05-10 17:52:49', 'order_location': 'Islamabad,Pakistan', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 41
# Message:  {'order_id': '41', 'order_product_name': 'Wrist Band', 'order_card_type': 'Visa', 'order_amount': 1366.07, 'order_datetime': '2024-05-10 17:52:50', 'order_location': 'Bangalore,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 42
# Message:  {'order_id': '42', 'order_product_name': 'Mobile Phone', 'order_card_type': 'Maestro', 'order_amount': 86.91, 'order_datetime': '2024-05-10 17:52:51', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 43
# Message:  {'order_id': '43', 'order_product_name': 'Mobile Phone', 'order_card_type': 'Maestro', 'order_amount': 1553.61, 'order_datetime': '2024-05-10 17:52:52', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 44
# Message:  {'order_id': '44', 'order_product_name': 'Laptop', 'order_card_type': 'Visa', 'order_amount': 128.36, 'order_datetime': '2024-05-10 17:52:53', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 45
# Message:  {'order_id': '45', 'order_product_name': 'Text Books', 'order_card_type': 'Maestro', 'order_amount': 981.88, 'order_datetime': '2024-05-10 17:52:54', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 46
# Message:  {'order_id': '46', 'order_product_name': 'LAN Cable', 'order_card_type': 'PayPal', 'order_amount': 257.58, 'order_datetime': '2024-05-10 17:52:55', 'order_location': 'Chennai,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 47
# Message:  {'order_id': '47', 'order_product_name': 'Mobile Phone', 'order_card_type': 'Visa', 'order_amount': 175.59, 'order_datetime': '2024-05-10 17:52:56', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 48
# Message:  {'order_id': '48', 'order_product_name': 'Mobile Phone', 'order_card_type': 'Visa', 'order_amount': 610.05, 'order_datetime': '2024-05-10 17:52:57', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 49
# Message:  {'order_id': '49', 'order_product_name': 'Text Books', 'order_card_type': 'Visa', 'order_amount': 1054.67, 'order_datetime': '2024-05-10 17:52:58', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 50
# Message:  {'order_id': '50', 'order_product_name': 'LAN Cable', 'order_card_type': 'Master', 'order_amount': 1500.81, 'order_datetime': '2024-05-10 17:52:59', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 51
# Message:  {'order_id': '51', 'order_product_name': 'TV Stand', 'order_card_type': 'PayPal', 'order_amount': 741.63, 'order_datetime': '2024-05-10 17:53:00', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 52
# Message:  {'order_id': '52', 'order_product_name': 'Wrist Band', 'order_card_type': 'Maestro', 'order_amount': 878.75, 'order_datetime': '2024-05-10 17:53:01', 'order_location': 'Islamabad,Pakistan', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 53
# Message:  {'order_id': '53', 'order_product_name': 'Pen Drive', 'order_card_type': 'Visa', 'order_amount': 43.86, 'order_datetime': '2024-05-10 17:53:02', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 54
# Message:  {'order_id': '54', 'order_product_name': 'Laptop', 'order_card_type': 'Maestro', 'order_amount': 384.38, 'order_datetime': '2024-05-10 17:53:03', 'order_location': 'Colombo,Sri Lanka', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 55
# Message:  {'order_id': '55', 'order_product_name': 'LAN Cable', 'order_card_type': 'Maestro', 'order_amount': 491.14, 'order_datetime': '2024-05-10 17:53:04', 'order_location': 'Pune,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 56
# Message:  {'order_id': '56', 'order_product_name': 'LAN Cable', 'order_card_type': 'PayPal', 'order_amount': 1295.24, 'order_datetime': '2024-05-10 17:53:05', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 57
# Message:  {'order_id': '57', 'order_product_name': 'Laptop', 'order_card_type': 'Visa', 'order_amount': 1329.94, 'order_datetime': '2024-05-10 17:53:06', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 58
# Message:  {'order_id': '58', 'order_product_name': 'Wrist Band', 'order_card_type': 'Maestro', 'order_amount': 1538.57, 'order_datetime': '2024-05-10 17:53:07', 'order_location': 'Singapore,Singapore', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 59
# Message:  {'order_id': '59', 'order_product_name': 'Mobile Phone', 'order_card_type': 'PhonePe', 'order_amount': 1124.27, 'order_datetime': '2024-05-10 17:53:08', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 60
# Message:  {'order_id': '60', 'order_product_name': 'Mobile Phone', 'order_card_type': 'PhonePe', 'order_amount': 759.5, 'order_datetime': '2024-05-10 17:53:09', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 61
# Message:  {'order_id': '61', 'order_product_name': 'HDMI Cable', 'order_card_type': 'American Express', 'order_amount': 1101.02, 'order_datetime': '2024-05-10 17:53:10', 'order_location': 'Colombo,Sri Lanka', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 62
# Message:  {'order_id': '62', 'order_product_name': 'LAN Cable', 'order_card_type': 'Maestro', 'order_amount': 925.99, 'order_datetime': '2024-05-10 17:53:11', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 63
# Message:  {'order_id': '63', 'order_product_name': 'LAN Cable', 'order_card_type': 'American Express', 'order_amount': 1154.11, 'order_datetime': '2024-05-10 17:53:12', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 64
# Message:  {'order_id': '64', 'order_product_name': 'External Hard Drive', 'order_card_type': 'Maestro', 'order_amount': 613.6, 'order_datetime': '2024-05-10 17:53:13', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 65
# Message:  {'order_id': '65', 'order_product_name': 'TV Stand', 'order_card_type': 'Master', 'order_amount': 548.58, 'order_datetime': '2024-05-10 17:53:14', 'order_location': 'Paris,France', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 66
# Message:  {'order_id': '66', 'order_product_name': 'Laptop', 'order_card_type': 'Maestro', 'order_amount': 849.63, 'order_datetime': '2024-05-10 17:53:15', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 67
# Message:  {'order_id': '67', 'order_product_name': 'Pen Drive', 'order_card_type': 'American Express', 'order_amount': 1368.22, 'order_datetime': '2024-05-10 17:53:16', 'order_location': 'Chennai,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 68
# Message:  {'order_id': '68', 'order_product_name': 'Laptop', 'order_card_type': 'Master', 'order_amount': 724.43, 'order_datetime': '2024-05-10 17:53:17', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 69
# Message:  {'order_id': '69', 'order_product_name': 'Laptop', 'order_card_type': 'Visa', 'order_amount': 1324.95, 'order_datetime': '2024-05-10 17:53:18', 'order_location': 'Singapore,Singapore', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 70
# Message:  {'order_id': '70', 'order_product_name': 'Pen Drive', 'order_card_type': 'American Express', 'order_amount': 1553.09, 'order_datetime': '2024-05-10 17:53:19', 'order_location': 'Pune,India', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 71
# Message:  {'order_id': '71', 'order_product_name': 'Laptop', 'order_card_type': 'PhonePe', 'order_amount': 866.23, 'order_datetime': '2024-05-10 17:53:20', 'order_location': 'Hyderabad,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 72
# Message:  {'order_id': '72', 'order_product_name': 'Pen Drive', 'order_card_type': 'Maestro', 'order_amount': 64.25, 'order_datetime': '2024-05-10 17:53:21', 'order_location': 'New York City,United States', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 73
# Message:  {'order_id': '73', 'order_product_name': 'Desktop Computer', 'order_card_type': 'Maestro', 'order_amount': 1495.62, 'order_datetime': '2024-05-10 17:53:22', 'order_location': 'Rome,Italy', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 74
# Message:  {'order_id': '74', 'order_product_name': 'External Hard Drive', 'order_card_type': 'Master', 'order_amount': 1372.12, 'order_datetime': '2024-05-10 17:53:23', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 75
# Message:  {'order_id': '75', 'order_product_name': 'LAN Cable', 'order_card_type': 'PayPal', 'order_amount': 399.01, 'order_datetime': '2024-05-10 17:53:24', 'order_location': 'Singapore,Singapore', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 76
# Message:  {'order_id': '76', 'order_product_name': 'HDMI Cable', 'order_card_type': 'Maestro', 'order_amount': 114.25, 'order_datetime': '2024-05-10 17:53:25', 'order_location': 'Paris,France', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 77
# Message:  {'order_id': '77', 'order_product_name': 'Wrist Watch', 'order_card_type': 'PayPal', 'order_amount': 207.42, 'order_datetime': '2024-05-10 17:53:26', 'order_location': 'Kolkata,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 78
# Message:  {'order_id': '78', 'order_product_name': 'TV', 'order_card_type': 'Visa', 'order_amount': 786.38, 'order_datetime': '2024-05-10 17:53:27', 'order_location': 'Pune,India', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 79
# Message:  {'order_id': '79', 'order_product_name': 'TV', 'order_card_type': 'PhonePe', 'order_amount': 602.39, 'order_datetime': '2024-05-10 17:53:28', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 80
# Message:  {'order_id': '80', 'order_product_name': 'Laptop', 'order_card_type': 'Maestro', 'order_amount': 1012.66, 'order_datetime': '2024-05-10 17:53:29', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 81
# Message:  {'order_id': '81', 'order_product_name': 'TV Stand', 'order_card_type': 'American Express', 'order_amount': 1114.48, 'order_datetime': '2024-05-10 17:53:30', 'order_location': 'Florida,United States', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 82
# Message:  {'order_id': '82', 'order_product_name': 'Text Books', 'order_card_type': 'Maestro', 'order_amount': 451.58, 'order_datetime': '2024-05-10 17:53:31', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 83
# Message:  {'order_id': '83', 'order_product_name': 'TV Stand', 'order_card_type': 'American Express', 'order_amount': 226.19, 'order_datetime': '2024-05-10 17:53:32', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 84
# Message:  {'order_id': '84', 'order_product_name': 'Pen Drive', 'order_card_type': 'PayPal', 'order_amount': 310.54, 'order_datetime': '2024-05-10 17:53:33', 'order_location': 'Beijing,China', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 85
# Message:  {'order_id': '85', 'order_product_name': 'Wrist Band', 'order_card_type': 'PayPal', 'order_amount': 1484.71, 'order_datetime': '2024-05-10 17:53:34', 'order_location': 'Bangalore,India', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 86
# Message:  {'order_id': '86', 'order_product_name': 'Pen Drive', 'order_card_type': 'American Express', 'order_amount': 252.07, 'order_datetime': '2024-05-10 17:53:35', 'order_location': 'Florida,United States', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 87
# Message:  {'order_id': '87', 'order_product_name': 'Wrist Band', 'order_card_type': 'PhonePe', 'order_amount': 1328.86, 'order_datetime': '2024-05-10 17:53:36', 'order_location': 'Ottawa,Canada', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 88
# Message:  {'order_id': '88', 'order_product_name': 'TV Stand', 'order_card_type': 'Visa', 'order_amount': 590.38, 'order_datetime': '2024-05-10 17:53:37', 'order_location': 'Florida,United States', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 89
# Message:  {'order_id': '89', 'order_product_name': 'Text Books', 'order_card_type': 'PayPal', 'order_amount': 49.57, 'order_datetime': '2024-05-10 17:53:38', 'order_location': 'New Delhi,Inida', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 90
# Message:  {'order_id': '90', 'order_product_name': 'Laptop', 'order_card_type': 'American Express', 'order_amount': 207.69, 'order_datetime': '2024-05-10 17:53:39', 'order_location': 'Islamabad,Pakistan', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 91
# Message:  {'order_id': '91', 'order_product_name': 'Laptop', 'order_card_type': 'PayPal', 'order_amount': 1110.78, 'order_datetime': '2024-05-10 17:53:40', 'order_location': 'Dhaka,Bangladesh', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 92
# Message:  {'order_id': '92', 'order_product_name': 'External Hard Drive', 'order_card_type': 'American Express', 'order_amount': 808.28, 'order_datetime': '2024-05-10 17:53:41', 'order_location': 'Rome,Italy', 'order_ecommerce_source': 'www.snapdeal.com'}
# Preparing message: 93
# Message:  {'order_id': '93', 'order_product_name': 'Desktop Computer', 'order_card_type': 'American Express', 'order_amount': 794.94, 'order_datetime': '2024-05-10 17:53:42', 'order_location': 'Singapore,Singapore', 'order_ecommerce_source': 'www.ebay.com'}
# Preparing message: 94
# Message:  {'order_id': '94', 'order_product_name': 'HDMI Cable', 'order_card_type': 'PayPal', 'order_amount': 1297.32, 'order_datetime': '2024-05-10 17:53:43', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 95
# Message:  {'order_id': '95', 'order_product_name': 'Laptop', 'order_card_type': 'American Express', 'order_amount': 361.51, 'order_datetime': '2024-05-10 17:53:44', 'order_location': 'Islamabad,Pakistan', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 96
# Message:  {'order_id': '96', 'order_product_name': 'External Hard Drive', 'order_card_type': 'Master', 'order_amount': 609.6, 'order_datetime': '2024-05-10 17:53:45', 'order_location': 'Singapore,Singapore', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 97
# Message:  {'order_id': '97', 'order_product_name': 'TV', 'order_card_type': 'American Express', 'order_amount': 561.25, 'order_datetime': '2024-05-10 17:53:46', 'order_location': 'Sydney,Australia', 'order_ecommerce_source': 'www.amazon.com'}
# Preparing message: 98
# Message:  {'order_id': '98', 'order_product_name': 'Desktop Computer', 'order_card_type': 'American Express', 'order_amount': 899.04, 'order_datetime': '2024-05-10 17:53:47', 'order_location': 'Jerusalem,Israel', 'order_ecommerce_source': 'www.flipkart.com'}
# Preparing message: 99
# Message:  {'order_id': '99', 'order_product_name': 'Wrist Watch', 'order_card_type': 'Maestro', 'order_amount': 199.13, 'order_datetime': '2024-05-10 17:53:48', 'order_location': 'Bangkok,Thailand', 'order_ecommerce_source': 'www.ebay.com'}
# Kafka Producer Application Completed.
